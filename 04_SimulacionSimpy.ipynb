# %%
import simpy
import random
import math
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
random.seed(42)

# %% [markdown]
# #### Base simulation. CP: 100 + Search for the optimal CP

# %%
# --- Función de formato de tiempo ---
def obtener_tiempo(minutos):
    minutos = int(minutos)
    return f"{(minutos//60)%24:02d}:{minutos%60:02d} día {minutos//(60*24)}"

# --- Clase Fabrica para centralizar recursos y contadores ---
class Fabrica:
    def __init__(self, env, critical_point, verbose=False):
        self.env = env
        self.critical_point = critical_point
        self.verbose = verbose 
        
        # Stocks de materiales (Containers para medir niveles)
        self.copper = simpy.Container(env, init=500, capacity=500)
        self.aluminum = simpy.Container(env, init=500, capacity=500)
        
        # Recursos 
        self.rotor_robots = simpy.Resource(env, capacity=2)
        self.stator_robots = simpy.Resource(env, capacity=2)
        self.rotor_inspectors = simpy.Resource(env, capacity=2)
        self.stator_inspectors = simpy.Resource(env, capacity=2)
        self.assembly_lines = simpy.Resource(env, capacity=3)
        
        # Almacenamiento intermedio y final
        self.ready_rotors = simpy.Store(env) # guardar piezas para ensamblar
        self.ready_stators = simpy.Store(env)
        self.warehouse = simpy.Container(env, capacity=20, init=0)
        
        # --- Estadísticas y Contador de Motores ---
        self.motores_finalizados = 0  
        self.stock_wait_times = []
        self.defective_rotors = 0
        self.total_rotors = 0
        self.defective_stators = 0
        self.total_stators = 0
        
        self.copper_ordered = False # no hay pedido de cobre en camino
        self.aluminum_ordered = False

# --- Procesos de la Línea de Montaje (Revisa constantemente el stock) ---

def check_stock(env, fabrica):
    while True:
        if fabrica.copper.level < fabrica.critical_point and not fabrica.copper_ordered:
            env.process(refill_stock(env, fabrica, 'cobre'))
        if fabrica.aluminum.level < fabrica.critical_point and not fabrica.aluminum_ordered:
            env.process(refill_stock(env, fabrica, 'aluminio'))
        yield env.timeout(1)

def refill_stock(env, fabrica, material):
    if material == 'cobre': fabrica.copper_ordered = True
    else: fabrica.aluminum_ordered = True
    
    if fabrica.verbose: 
        print(f"[{obtener_tiempo(env.now)}] REQUEST: Order for {material} placed.")
    
    yield env.timeout(8 * 60) # 8 horas de espera
    
    amount = 200
    if material == 'cobre':
        actual_add = min(amount, 500 - fabrica.copper.level)
        yield fabrica.copper.put(actual_add)
        fabrica.copper_ordered = False
    else:
        actual_add = min(amount, 500 - fabrica.aluminum.level)
        yield fabrica.aluminum.put(actual_add)
        fabrica.aluminum_ordered = False
        
    if fabrica.verbose: 
        print(f"[{obtener_tiempo(env.now)}] RESTOCK: Arrival of {material} completed.")

def fabricar_pieza(env, fabrica, tipo):
    resource = fabrica.rotor_robots if tipo == 'rotor' else fabrica.stator_robots
    mean_time = 60 if tipo == 'rotor' else 120

    while True:
        with resource.request() as req:
            yield req
            
            # Medir tiempo de espera por stock
            start_wait = env.now
            while fabrica.copper.level < 8 or fabrica.aluminum.level < 8:
                yield env.timeout(1) 
            
            wait_duration = env.now - start_wait
            if wait_duration > 0:
                fabrica.stock_wait_times.append(wait_duration)

            # Consumo de stock 
            yield fabrica.copper.get(8) & fabrica.aluminum.get(8)

            fab_time = max(30, random.normalvariate(mean_time, 30)) 
            yield env.timeout(fab_time)
            
            if fabrica.verbose:
                print(f"[{obtener_tiempo(env.now)}] FABRICATION: {tipo} finished.")
            
            env.process(inspeccionar_pieza(env, fabrica, tipo, fab_time))

def inspeccionar_pieza(env, fabrica, tipo, fab_time):
    resource = fabrica.rotor_inspectors if tipo == 'rotor' else fabrica.stator_inspectors
    mean_insp = 120 if tipo == 'rotor' else 60
    
    # Probabilidad de defecto p(t)
    prob_defecto = 1 / (1 + math.exp((fab_time - 40) / 13))
    
    with resource.request() as req:
        yield req
        insp_time = max(30, random.normalvariate(mean_insp, 30))
        yield env.timeout(insp_time)
        
        is_defective = random.random() < prob_defecto 
        
        if tipo == 'rotor':
            fabrica.total_rotors += 1
            if is_defective:
                fabrica.defective_rotors += 1
            else:
                yield fabrica.ready_rotors.put(True)
        else:
            fabrica.total_stators += 1
            if is_defective:
                fabrica.defective_stators += 1
            else:
                yield fabrica.ready_stators.put(True)

def ensamblar_motor(env, fabrica):
    while True:
        # Necesitamos 1 rotor y 1 estator listos
        yield fabrica.ready_rotors.get()
        yield fabrica.ready_stators.get()
        
        with fabrica.assembly_lines.request() as req: # Pedir línea de ensamblaje
            yield req
            ass_time = max(30, random.normalvariate(120, 60))
            yield env.timeout(ass_time)
            
            # Incrementar contador de motores creados
            fabrica.motores_finalizados += 1
            yield fabrica.warehouse.put(1)
            
            if fabrica.verbose:
                print(f"[{obtener_tiempo(env.now)}] ASSEMBLY: Engine #{fabrica.motores_finalizados} sent to the warehouse.")

            if fabrica.warehouse.level == 20:
                yield fabrica.warehouse.get(20)
                if fabrica.verbose:
                    print(f"[{obtener_tiempo(env.now)}] LOGISTICS: Warehouse full. 20 engines removed.")

# %%
# --- Ejecución de la Simulación ---

def run_simulation(critical_point, verbose=False):
    env = simpy.Environment()
    fabrica = Fabrica(env, critical_point, verbose)
    
    env.process(check_stock(env, fabrica))
    for _ in range(2): env.process(fabricar_pieza(env, fabrica, 'rotor')) # Crear 2 procesos paralelos fabricando rotores
    for _ in range(2): env.process(fabricar_pieza(env, fabrica, 'stator'))
    for _ in range(3): env.process(ensamblar_motor(env, fabrica))
    
    env.run(until=7200) # 5 días
    
    avg_wait = np.mean(fabrica.stock_wait_times) if fabrica.stock_wait_times else 0
    p_def_rotor = (fabrica.defective_rotors / fabrica.total_rotors * 100) if fabrica.total_rotors > 0 else 0
    p_def_stator = (fabrica.defective_stators / fabrica.total_stators * 100) if fabrica.total_stators > 0 else 0
    
    return avg_wait, p_def_rotor, p_def_stator, fabrica.motores_finalizados

# Simulación de prueba
wait, pr, ps, total = run_simulation(100, verbose=True)

print(f"\n" + "="*30)
print(f"FINAL RESULTS (CP=100)")
print(f"="*30)
print(f"Total of engines created: {total}")
print(f"Average stock waiting time: {wait:.2f} min")
print(f"Defective rotors: {pr:.2f}%")
print(f"Defective stators: {ps:.2f}%")

# --- GRÁFICO DEL PUNTO CRÍTICO ---
puntos_test = range(50, 401, 50)
resultados_grafico = []

for cp in puntos_test:
    esperas = []
    for _ in range(10):
        w, _, _, _ = run_simulation(cp, verbose=False)
        esperas.append(w)
    resultados_grafico.append({'Critical Point': cp, 'Average Wait (min)': np.mean(esperas)})

df = pd.DataFrame(resultados_grafico)
plt.figure(figsize=(10, 6))
plt.plot(df['Critical Point'], df['Average Wait (min)'], marker='o', color='b')
plt.title('Optimization of the Critical Point vs Waiting Time')
plt.xlabel('Critical Point')
plt.ylabel('Average Waiting Time (min)')
plt.grid(True)
plt.show()


print("\n--- Final Results ---")
print(df)
# Out:
# [00:45 día 0] FABRICATION: rotor finished.
# [01:07 día 0] FABRICATION: rotor finished.
# [01:55 día 0] FABRICATION: stator finished.
# [02:02 día 0] FABRICATION: rotor finished.
# [02:37 día 0] FABRICATION: stator finished.
# [02:59 día 0] FABRICATION: rotor finished.
# [03:47 día 0] FABRICATION: rotor finished.
# [03:47 día 0] FABRICATION: rotor finished.
# [04:26 día 0] ASSEMBLY: Engine #1 sent to the warehouse.
# [04:31 día 0] FABRICATION: stator finished.
# [04:39 día 0] FABRICATION: rotor finished.
# [04:58 día 0] FABRICATION: rotor finished.
# [05:13 día 0] ASSEMBLY: Engine #2 sent to the warehouse.
# [05:22 día 0] FABRICATION: stator finished.
# [06:26 día 0] FABRICATION: rotor finished.
# [06:39 día 0] FABRICATION: rotor finished.
# [06:45 día 0] ASSEMBLY: Engine #3 sent to the warehouse.
# [06:47 día 0] FABRICATION: stator finished.
# [06:57 día 0] FABRICATION: rotor finished.
# [07:27 día 0] FABRICATION: rotor finished.
# [08:01 día 0] FABRICATION: stator finished.
# [08:02 día 0] FABRICATION: rotor finished.
# [08:05 día 0] FABRICATION: rotor finished.
# [08:36 día 0] ASSEMBLY: Engine #4 sent to the warehouse.
# [08:55 día 0] FABRICATION: rotor finished.
# [09:05 día 0] ASSEMBLY: Engine #5 sent to the warehouse.
# [09:07 día 0] FABRICATION: stator finished.
# [09:33 día 0] FABRICATION: rotor finished.
# [10:30 día 0] FABRICATION: stator finished.
# [10:46 día 0] FABRICATION: rotor finished.
# [10:47 día 0] ASSEMBLY: Engine #6 sent to the warehouse.
# [10:52 día 0] FABRICATION: rotor finished.
# [10:58 día 0] ASSEMBLY: Engine #7 sent to the warehouse.
# [11:11 día 0] FABRICATION: stator finished.
# [11:17 día 0] FABRICATION: rotor finished.
# [12:02 día 0] ASSEMBLY: Engine #8 sent to the warehouse.
# [12:03 día 0] FABRICATION: rotor finished.
# [12:10 día 0] FABRICATION: rotor finished.
# [12:33 día 0] FABRICATION: rotor finished.
# [12:39 día 0] FABRICATION: stator finished.
# [12:54 día 0] FABRICATION: rotor finished.
# [13:50 día 0] FABRICATION: rotor finished.
# [14:07 día 0] ASSEMBLY: Engine #9 sent to the warehouse.
# [14:14 día 0] FABRICATION: rotor finished.
# [14:14 día 0] FABRICATION: stator finished.
# [14:27 día 0] FABRICATION: stator finished.
# [14:59 día 0] FABRICATION: rotor finished.
# [15:15 día 0] FABRICATION: rotor finished.
# [15:36 día 0] ASSEMBLY: Engine #10 sent to the warehouse.
# [15:45 día 0] FABRICATION: rotor finished.
# [15:55 día 0] ASSEMBLY: Engine #11 sent to the warehouse.
# [16:08 día 0] FABRICATION: rotor finished.
# [16:18 día 0] FABRICATION: rotor finished.
# [16:30 día 0] FABRICATION: stator finished.
# [16:48 día 0] FABRICATION: rotor finished.
# [16:54 día 0] FABRICATION: stator finished.
# [17:00 día 0] FABRICATION: rotor finished.
# [17:09 día 0] ASSEMBLY: Engine #12 sent to the warehouse.
# [17:18 día 0] FABRICATION: rotor finished.
# [17:19 día 0] REQUEST: Order for cobre placed.
# [17:19 día 0] REQUEST: Order for aluminio placed.
# [18:14 día 0] FABRICATION: rotor finished.
# [18:28 día 0] FABRICATION: rotor finished.
# [18:49 día 0] FABRICATION: stator finished.
# [19:03 día 0] FABRICATION: stator finished.
# [19:07 día 0] ASSEMBLY: Engine #13 sent to the warehouse.
# [19:13 día 0] FABRICATION: rotor finished.
# [19:31 día 0] FABRICATION: stator finished.
# [19:40 día 0] FABRICATION: rotor finished.
# [19:43 día 0] FABRICATION: rotor finished.
# [20:02 día 0] ASSEMBLY: Engine #14 sent to the warehouse.
# [20:52 día 0] FABRICATION: rotor finished.
# [21:16 día 0] FABRICATION: rotor finished.
# [21:23 día 0] FABRICATION: stator finished.
# [21:35 día 0] ASSEMBLY: Engine #15 sent to the warehouse.
# [21:37 día 0] ASSEMBLY: Engine #16 sent to the warehouse.
# [22:04 día 0] FABRICATION: stator finished.
# [22:39 día 0] FABRICATION: rotor finished.
# [23:15 día 0] FABRICATION: stator finished.
# [23:20 día 0] FABRICATION: rotor finished.
# [00:14 día 1] ASSEMBLY: Engine #17 sent to the warehouse.
# [01:19 día 1] RESTOCK: Arrival of cobre completed.
# [01:19 día 1] RESTOCK: Arrival of aluminio completed.
# [01:56 día 1] ASSEMBLY: Engine #18 sent to the warehouse.
# [02:10 día 1] FABRICATION: rotor finished.
# [02:39 día 1] FABRICATION: rotor finished.
# [02:40 día 1] FABRICATION: rotor finished.
# [02:41 día 1] FABRICATION: stator finished.
# [03:27 día 1] FABRICATION: stator finished.
# [03:29 día 1] FABRICATION: rotor finished.
# [03:40 día 1] FABRICATION: rotor finished.
# [04:12 día 1] FABRICATION: rotor finished.
# [04:23 día 1] ASSEMBLY: Engine #19 sent to the warehouse.
# [05:11 día 1] FABRICATION: rotor finished.
# [05:15 día 1] FABRICATION: rotor finished.
# [05:16 día 1] REQUEST: Order for cobre placed.
# [05:16 día 1] REQUEST: Order for aluminio placed.
# [05:33 día 1] FABRICATION: stator finished.
# [05:51 día 1] FABRICATION: stator finished.
# [06:05 día 1] FABRICATION: rotor finished.
# [06:11 día 1] ASSEMBLY: Engine #20 sent to the warehouse.
# [06:11 día 1] LOGISTICS: Warehouse full. 20 engines removed.
# [06:22 día 1] FABRICATION: rotor finished.
# [06:28 día 1] ASSEMBLY: Engine #21 sent to the warehouse.
# [06:52 día 1] FABRICATION: rotor finished.
# [07:12 día 1] FABRICATION: stator finished.
# [07:45 día 1] FABRICATION: rotor finished.
# 1             100          198.789931
# 2             150           66.981642
# 3             200           18.470714
# 4             250            0.000000
# 5             300            0.000000
# 6             350            0.000000
# 7             400            0.000000

# %% [markdown]
# #### Results with the optimal CP (250)

# %%
wait, pr, ps, total = run_simulation(250, verbose=True)

print(f"\n" + "="*30)
print(f"FINAL RESULTS (CP=100)")
print(f"="*30)
print(f"Total of engines created: {total}")
print(f"Average stock waiting time: {wait:.2f} min")
print(f"Defective rotors: {pr:.2f}%")
print(f"Defective stators: {ps:.2f}%")
# Out:
# [01:01 día 0] FABRICATION: rotor finished.
# [01:28 día 0] FABRICATION: stator finished.
# [01:31 día 0] FABRICATION: rotor finished.
# [01:51 día 0] FABRICATION: rotor finished.
# [02:01 día 0] FABRICATION: stator finished.
# [02:04 día 0] FABRICATION: rotor finished.
# [02:51 día 0] FABRICATION: stator finished.
# [03:00 día 0] FABRICATION: rotor finished.
# [03:40 día 0] FABRICATION: rotor finished.
# [03:47 día 0] FABRICATION: stator finished.
# [03:59 día 0] FABRICATION: rotor finished.
# [04:16 día 0] FABRICATION: rotor finished.
# [04:24 día 0] FABRICATION: stator finished.
# [04:41 día 0] ASSEMBLY: Engine #1 sent to the warehouse.
# [04:54 día 0] FABRICATION: stator finished.
# [04:55 día 0] FABRICATION: rotor finished.
# [05:54 día 0] FABRICATION: rotor finished.
# [06:17 día 0] FABRICATION: rotor finished.
# [06:18 día 0] ASSEMBLY: Engine #2 sent to the warehouse.
# [06:30 día 0] FABRICATION: stator finished.
# [06:40 día 0] FABRICATION: stator finished.
# [07:33 día 0] FABRICATION: rotor finished.
# [07:45 día 0] FABRICATION: rotor finished.
# [07:49 día 0] ASSEMBLY: Engine #3 sent to the warehouse.
# [08:08 día 0] FABRICATION: stator finished.
# [08:09 día 0] FABRICATION: stator finished.
# [08:11 día 0] FABRICATION: rotor finished.
# [08:20 día 0] ASSEMBLY: Engine #4 sent to the warehouse.
# [08:59 día 0] FABRICATION: rotor finished.
# [09:10 día 0] ASSEMBLY: Engine #5 sent to the warehouse.
# [09:11 día 0] FABRICATION: rotor finished.
# [09:34 día 0] FABRICATION: stator finished.
# [09:36 día 0] ASSEMBLY: Engine #6 sent to the warehouse.
# [09:45 día 0] FABRICATION: rotor finished.
# [09:46 día 0] REQUEST: Order for cobre placed.
# [09:46 día 0] REQUEST: Order for aluminio placed.
# [09:58 día 0] ASSEMBLY: Engine #7 sent to the warehouse.
# [10:08 día 0] FABRICATION: rotor finished.
# [10:17 día 0] FABRICATION: rotor finished.
# [10:18 día 0] FABRICATION: stator finished.
# [10:38 día 0] FABRICATION: rotor finished.
# [11:29 día 0] FABRICATION: rotor finished.
# [11:30 día 0] FABRICATION: stator finished.
# [12:11 día 0] FABRICATION: rotor finished.
# [12:18 día 0] FABRICATION: stator finished.
# [12:41 día 0] FABRICATION: rotor finished.
# [12:49 día 0] FABRICATION: rotor finished.
# [13:19 día 0] FABRICATION: rotor finished.
# [13:20 día 0] ASSEMBLY: Engine #8 sent to the warehouse.
# [13:28 día 0] ASSEMBLY: Engine #9 sent to the warehouse.
# [13:47 día 0] FABRICATION: stator finished.
# [14:12 día 0] FABRICATION: stator finished.
# [14:34 día 0] FABRICATION: rotor finished.
# [14:36 día 0] FABRICATION: rotor finished.
# [15:11 día 0] FABRICATION: rotor finished.
# [15:31 día 0] ASSEMBLY: Engine #10 sent to the warehouse.
# [15:55 día 0] FABRICATION: rotor finished.
# [16:12 día 0] FABRICATION: rotor finished.
# [16:18 día 0] FABRICATION: stator finished.
# [16:20 día 0] FABRICATION: stator finished.
# [16:57 día 0] FABRICATION: rotor finished.
# [17:17 día 0] FABRICATION: stator finished.
# [17:46 día 0] RESTOCK: Arrival of cobre completed.
# [17:46 día 0] RESTOCK: Arrival of aluminio completed.
# [18:23 día 0] ASSEMBLY: Engine #11 sent to the warehouse.
# [18:33 día 0] FABRICATION: stator finished.
# [18:50 día 0] FABRICATION: rotor finished.
# [18:57 día 0] FABRICATION: rotor finished.
# [18:58 día 0] REQUEST: Order for cobre placed.
# [18:58 día 0] REQUEST: Order for aluminio placed.
# [19:11 día 0] FABRICATION: stator finished.
# [19:24 día 0] ASSEMBLY: Engine #12 sent to the warehouse.
# [19:52 día 0] FABRICATION: rotor finished.
# [20:00 día 0] FABRICATION: stator finished.
# [20:09 día 0] FABRICATION: rotor finished.
# [20:40 día 0] FABRICATION: rotor finished.
# [20:43 día 0] ASSEMBLY: Engine #13 sent to the warehouse.
# [21:05 día 0] FABRICATION: stator finished.
# [21:15 día 0] ASSEMBLY: Engine #14 sent to the warehouse.
# [21:28 día 0] FABRICATION: rotor finished.
# [21:38 día 0] ASSEMBLY: Engine #15 sent to the warehouse.
# [21:50 día 0] FABRICATION: stator finished.
# [22:14 día 0] FABRICATION: rotor finished.
# [22:22 día 0] ASSEMBLY: Engine #16 sent to the warehouse.
# [22:39 día 0] FABRICATION: rotor finished.
# [23:09 día 0] FABRICATION: rotor finished.
# [23:10 día 0] FABRICATION: stator finished.
# [23:39 día 0] FABRICATION: stator finished.
# [23:47 día 0] ASSEMBLY: Engine #17 sent to the warehouse.
# [00:00 día 1] FABRICATION: rotor finished.
# [00:30 día 1] FABRICATION: rotor finished.
# [00:48 día 1] FABRICATION: rotor finished.
# [01:00 día 1] FABRICATION: rotor finished.
# [01:30 día 1] FABRICATION: rotor finished.
# [01:32 día 1] FABRICATION: stator finished.
# [01:53 día 1] FABRICATION: stator finished.
# [01:55 día 1] ASSEMBLY: Engine #18 sent to the warehouse.
# [02:23 día 1] FABRICATION: rotor finished.
# [02:42 día 1] FABRICATION: rotor finished.
# [02:49 día 1] FABRICATION: stator finished.
# [02:53 día 1] FABRICATION: rotor finished.
# [02:58 día 1] RESTOCK: Arrival of cobre completed.
# [02:58 día 1] RESTOCK: Arrival of aluminio completed.
# [03:14 día 1] FABRICATION: stator finished.
# [03:15 día 1] REQUEST: Order for cobre placed.
# [03:15 día 1] REQUEST: Order for aluminio placed.
# [03:41 día 1] FABRICATION: rotor finished.
# [03:54 día 1] ASSEMBLY: Engine #19 sent to the warehouse.
# [03:58 día 1] FABRICATION: rotor finished.
# [04:30 día 1] FABRICATION: rotor finished.
# [04:51 día 1] FABRICATION: rotor finished.
# [05:22 día 1] ASSEMBLY: Engine #20 sent to the warehouse.
# [05:22 día 1] LOGISTICS: Warehouse full. 20 engines removed.
# [05:24 día 1] FABRICATION: stator finished.
# [05:24 día 1] FABRICATION: rotor finished.
# [05:28 día 1] FABRICATION: rotor finished.
# [05:56 día 1] FABRICATION: stator finished.
# [06:20 día 1] FABRICATION: rotor finished.
# [06:41 día 1] ASSEMBLY: Engine #21 sent to the warehouse.
# [06:50 día 1] FABRICATION: rotor finished.
# [07:03 día 1] FABRICATION: stator finished.
# [07:14 día 1] FABRICATION: rotor finished.
# [07:34 día 1] FABRICATION: stator finished.
# [07:37 día 1] ASSEMBLY: Engine #22 sent to the warehouse.
# [07:50 día 1] FABRICATION: rotor finished.
# [08:29 día 1] FABRICATION: rotor finished.
# [08:38 día 1] FABRICATION: rotor finished.
# [09:00 día 1] ASSEMBLY: Engine #23 sent to the warehouse.
# [09:18 día 1] FABRICATION: stator finished.
# [09:32 día 1] FABRICATION: rotor finished.
# [09:38 día 1] FABRICATION: rotor finished.
# [10:02 día 1] FABRICATION: stator finished.
# [10:45 día 1] ASSEMBLY: Engine #24 sent to the warehouse.
# [10:48 día 1] FABRICATION: rotor finished.
# [11:10 día 1] FABRICATION: rotor finished.
# [11:15 día 1] RESTOCK: Arrival of cobre completed.
# [11:15 día 1] RESTOCK: Arrival of aluminio completed.
# [11:21 día 1] FABRICATION: rotor finished.
# [11:29 día 1] FABRICATION: stator finished.
# [12:00 día 1] FABRICATION: rotor finished.
# [12:01 día 1] REQUEST: Order for cobre placed.
# [12:01 día 1] REQUEST: Order for aluminio placed.
# [12:08 día 1] FABRICATION: rotor finished.
# [12:33 día 1] ASSEMBLY: Engine #25 sent to the warehouse.
# [12:41 día 1] FABRICATION: stator finished.
# [13:11 día 1] FABRICATION: stator finished.
# [13:12 día 1] FABRICATION: rotor finished.
# [13:33 día 1] FABRICATION: rotor finished.
# [14:12 día 1] ASSEMBLY: Engine #26 sent to the warehouse.
# [14:12 día 1] FABRICATION: stator finished.
# [14:22 día 1] FABRICATION: rotor finished.
# [14:31 día 1] ASSEMBLY: Engine #27 sent to the warehouse.
# [14:38 día 1] FABRICATION: rotor finished.
# [15:08 día 1] ASSEMBLY: Engine #28 sent to the warehouse.
# [15:35 día 1] FABRICATION: rotor finished.
# [15:43 día 1] FABRICATION: stator finished.
# [15:47 día 1] FABRICATION: rotor finished.
# [16:30 día 1] ASSEMBLY: Engine #29 sent to the warehouse.
# [16:48 día 1] FABRICATION: rotor finished.
# [16:51 día 1] FABRICATION: stator finished.
# [17:03 día 1] FABRICATION: rotor finished.
# [17:51 día 1] FABRICATION: stator finished.
# [18:17 día 1] FABRICATION: rotor finished.
# [18:24 día 1] FABRICATION: rotor finished.
# [18:55 día 1] ASSEMBLY: Engine #30 sent to the warehouse.
# [19:23 día 1] ASSEMBLY: Engine #31 sent to the warehouse.
# [17:39 día 4] FABRICATION: stator finished.
# [18:37 día 4] FABRICATION: rotor finished.
# [18:44 día 4] ASSEMBLY: Engine #85 sent to the warehouse.
# [18:48 día 4] FABRICATION: stator finished.
# [18:58 día 4] ASSEMBLY: Engine #86 sent to the warehouse.
# [19:07 día 4] FABRICATION: rotor finished.
# [19:08 día 4] FABRICATION: rotor finished.
# [19:16 día 4] RESTOCK: Arrival of cobre completed.
# [19:16 día 4] RESTOCK: Arrival of aluminio completed.
# [19:17 día 4] REQUEST: Order for cobre placed.
# [19:17 día 4] REQUEST: Order for aluminio placed.
# [19:21 día 4] ASSEMBLY: Engine #87 sent to the warehouse.
# [19:21 día 4] ASSEMBLY: Engine #88 sent to the warehouse.
# [19:38 día 4] FABRICATION: stator finished.
# [19:58 día 4] FABRICATION: rotor finished.
# [20:27 día 4] FABRICATION: rotor finished.
# [21:00 día 4] FABRICATION: stator finished.
# [21:04 día 4] FABRICATION: rotor finished.
# [21:18 día 4] FABRICATION: stator finished.
# [21:25 día 4] ASSEMBLY: Engine #89 sent to the warehouse.
# [21:34 día 4] FABRICATION: rotor finished.
# [21:55 día 4] FABRICATION: rotor finished.
# [22:21 día 4] FABRICATION: rotor finished.
# [22:32 día 4] FABRICATION: rotor finished.
# [23:07 día 4] FABRICATION: stator finished.
# [23:07 día 4] FABRICATION: rotor finished.
# [23:09 día 4] FABRICATION: rotor finished.
# [23:25 día 4] ASSEMBLY: Engine #90 sent to the warehouse.
# [23:37 día 4] FABRICATION: rotor finished.
#
# ==============================
# FINAL RESULTS (CP=100)
# ==============================
# Total of engines created: 90
# Average stock waiting time: 0.00 min
# Defective rotors: 21.37%
# Defective stators: 0.84%

# %% [markdown]
# #### Search for the optimal number of robots

# %%
# Prueba: Número de robots

robots_list = [1, 2, 3, 4]

resultados_robots = []

# Modificar la clase Fabrica para cambiar número de robots
class Fabrica:
    def __init__(self, env, critical_point, rotor_robots=2, stator_robots=2, verbose=False):
        self.env = env
        self.critical_point = critical_point
        self.verbose = verbose 
        
        # Stocks de materiales
        self.copper = simpy.Container(env, init=500, capacity=500)
        self.aluminum = simpy.Container(env, init=500, capacity=500)
        
        # Recursos 
        self.rotor_robots = simpy.Resource(env, capacity=rotor_robots)
        self.stator_robots = simpy.Resource(env, capacity=stator_robots)
        self.rotor_inspectors = simpy.Resource(env, capacity=2)
        self.stator_inspectors = simpy.Resource(env, capacity=2)
        self.assembly_lines = simpy.Resource(env, capacity=3)
        
        # Almacenamiento intermedio y final
        self.ready_rotors = simpy.Store(env)
        self.ready_stators = simpy.Store(env)
        self.warehouse = simpy.Container(env, capacity=20, init=0)
        
        # Estadísticas
        self.motores_finalizados = 0  
        self.stock_wait_times = []
        self.defective_rotors = 0
        self.total_rotors = 0
        self.defective_stators = 0
        self.total_stators = 0
        
        self.copper_ordered = False
        self.aluminum_ordered = False

# Ajustamos run_simulation para aceptar número de robots
def run_simulation(critical_point, rotor_robots=2, stator_robots=2, verbose=False):
    env = simpy.Environment()
    fabrica = Fabrica(env, critical_point, rotor_robots, stator_robots, verbose)
    
    env.process(check_stock(env, fabrica))
    for _ in range(rotor_robots): env.process(fabricar_pieza(env, fabrica, 'rotor'))
    for _ in range(stator_robots): env.process(fabricar_pieza(env, fabrica, 'stator'))
    for _ in range(3): env.process(ensamblar_motor(env, fabrica))
    
    env.run(until=7200)
    
    return fabrica.motores_finalizados

# Ejecutamos experimento
for r in robots_list:
    motores = []
    for _ in range(10):  
        total = run_simulation(critical_point=100, rotor_robots=r, stator_robots=r)
        motores.append(total)
    
    resultados_robots.append({
        "Robots": r,
        "Average Engines": np.mean(motores)
    })

df_robots = pd.DataFrame(resultados_robots)

# Imprimir tabla
print("Robot experiment results:")
print(df_robots)

# --- gráfico ---
plt.figure(figsize=(8,5))
plt.plot(df_robots["Robots"], df_robots["Average Engines"], marker="o", color="green")
plt.title("Number of Robots vs Engine Production")
plt.xlabel("Robots per Station")
plt.ylabel("Engines Produced (Average)")
plt.grid(True)
plt.show()
# Out:
# Robot experiment results:
#    Robots  Average Engines
# 0       1             57.4
# 1       2             86.0
# 2       3             84.3
# 3       4             82.7

# %% [markdown]
# #### Variation of parameters for the best combination

# %%
# --- Clase Fabrica Centralizada ---
class Fabrica:
    def __init__(self, env, cp, rq, n_robots, var_provider):
        self.env = env
        self.cp = cp                
        self.rq = rq                # Cantidad de recarga (Replenishment Qty)
        self.n_robots = n_robots    
        self.var_provider = var_provider 
        self.motores_fabricados = 0
        
        # Stocks
        self.copper = simpy.Container(env, init=500, capacity=500)
        self.aluminum = simpy.Container(env, init=500, capacity=500)
        
        # Recursos
        self.rotor_robots = simpy.Resource(env, capacity=n_robots)
        self.stator_robots = simpy.Resource(env, capacity=n_robots)
        self.rotor_inspectors = simpy.Resource(env, capacity=2)
        self.stator_inspectors = simpy.Resource(env, capacity=2)
        self.assembly_lines = simpy.Resource(env, capacity=3)
        
        self.ready_rotors = simpy.Store(env)
        self.ready_stators = simpy.Store(env)
        
        # Registro para el Gráfico
        self.stock_history = {'time': [], 'copper': [], 'aluminum': []}
        self.env.process(self.monitor_stock())
        
        self.copper_ordered = False
        self.aluminum_ordered = False

    def monitor_stock(self):
        """Registra los niveles de stock cada hora para graficar."""
        while True:
            self.stock_history['time'].append(self.env.now / 60) # Guardar en horas
            self.stock_history['copper'].append(self.copper.level)
            self.stock_history['aluminum'].append(self.aluminum.level)
            yield self.env.timeout(10) # Muestreo cada 10 min

# --- Procesos de Soporte ---

def refill_stock(env, fabrica, material):
    if material == 'cobre': fabrica.copper_ordered = True
    else: fabrica.aluminum_ordered = True
    
    # Tiempo de espera fijo 8h
    wait_time = 8 * 60
    yield env.timeout(wait_time)
    
    add = min(fabrica.rq, 500 - (fabrica.copper.level if material == 'cobre' else fabrica.aluminum.level))
    if material == 'cobre':
        yield fabrica.copper.put(add)
        fabrica.copper_ordered = False
    else:
        yield fabrica.aluminum.put(add)
        fabrica.aluminum_ordered = False

def check_stock_logic(env, fabrica):
    while True:
        if fabrica.copper.level < fabrica.cp and not fabrica.copper_ordered:
            env.process(refill_stock(env, fabrica, 'cobre'))
        if fabrica.aluminum.level < fabrica.cp and not fabrica.aluminum_ordered:
            env.process(refill_stock(env, fabrica, 'aluminio'))
        yield env.timeout(5)

def fabricar_pieza(env, fabrica, tipo):
    resource = fabrica.rotor_robots if tipo == 'rotor' else fabrica.stator_robots
    mean_time = 60 if tipo == 'rotor' else 120
    
    while True:
        with resource.request() as req:
            yield req
            
            while fabrica.copper.level < 8 or fabrica.aluminum.level < 8:
                yield env.timeout(1)
            
            yield fabrica.copper.get(8)
            yield fabrica.aluminum.get(8)
            
            yield env.timeout(max(30, random.normalvariate(mean_time, 30)))
            
            # Guardar pieza terminada
            if tipo == 'rotor':
                yield fabrica.ready_rotors.put(1)
            else:
                yield fabrica.ready_stators.put(1)

def ensamblar_motor(env, fabrica):
    while True:
        with fabrica.assembly_lines.request() as req:
            yield req
            
            # Esperar a tener ambas piezas
            yield fabrica.ready_rotors.get()
            yield fabrica.ready_stators.get()
            
            # Tiempo de ensamblaje
            yield env.timeout(90)  # ajustable
            
            # Motor terminado
            fabrica.motores_fabricados += 1

def plot_stock_levels(stock_data_list, cp, rq, robots, var):
    plt.figure(figsize=(12, 5))
    # Graficamos solo la primera simulación del lote para no saturar el gráfico
    data = stock_data_list[0]
    plt.plot(data['time'], data['copper'], label='Cobre', color='orange', alpha=0.8)
    plt.plot(data['time'], data['aluminum'], label='Aluminio', color='blue', alpha=0.6)
    
    plt.axhline(y=cp, color='r', linestyle='--', label=f'Punto Crítico ({cp})')
    
    plt.title(f"Stock Behavior | CP: {cp}, Restock: {rq}, Robots: {robots}")
    plt.xlabel('Time (hours)')
    plt.ylabel('Unit Level')
    plt.legend(loc='upper right')
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.show()

# --- Orquestador ---

def run_experiment(cp, rq, robots, var):
    all_sims_data = []
    motores_totales = []
    
    for _ in range(5):
        env = simpy.Environment()
        f = Fabrica(env, cp, rq, robots, var)
        
        env.process(check_stock_logic(env, f))
        
        for _ in range(robots):
            env.process(fabricar_pieza(env, f, 'rotor'))
            env.process(fabricar_pieza(env, f, 'stator'))
        
        for _ in range(3):
            env.process(ensamblar_motor(env, f))
            
        env.run(until=7200)
        
        all_sims_data.append(f.stock_history)
        motores_totales.append(f.motores_fabricados)
    
    print(f"Average engines produced: {sum(motores_totales)/len(motores_totales)}")
    
    plot_stock_levels(all_sims_data, cp, rq, robots, var)
    return all_sims_data, motores_totales

# --- Ejecución de Pruebas Variando Parámetros ---

# Parámetros a probar
puntos_criticos = [150 ,250]
cantidades_recarga = [200, 300, 400]
robots_opciones = [2, 3]

for n_rob in robots_opciones:
    for cp in puntos_criticos:
        for rq in cantidades_recarga:
            data = run_experiment(cp, rq, n_rob, var=False)
# Out:
# Average engines produced: 110.8
# Average engines produced: 112.2
# Average engines produced: 113.6
# Average engines produced: 117.0
# Average engines produced: 115.6
# Average engines produced: 115.6
# Average engines produced: 126.8
# Average engines produced: 138.2
# Average engines produced: 146.0
# Average engines produced: 137.4
# Average engines produced: 171.0
# Average engines produced: 169.2
